# %% [markdown]
# <a href="https://colab.research.google.com/github/suruanush/Pandas/blob/main/Pandas_Basics_and_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas
# - **Pandas** is a fast, powerful and easy to use open source data analysis and manipulation library.
# 1. Series
# 2. DataFrame

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')     # To avoid warnings

# %% [markdown]
# # 1. Series

# %%
data = [10,20,30,40,50]
s1 = pd.Series(data)
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1.values # returns the data in the form of an ndarray
# Out:
# array([10, 20, 30, 40, 50])

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s1.dtype
# Out:
# dtype('int64')

# %%
list(s1.index)
# Out:
# [0, 1, 2, 3, 4]

# %%
s1.index = [101,102,103,104,105]
s1
# Out:
# 101    10
# 102    20
# 103    30
# 104    40
# 105    50
# dtype: int64

# %%
s1.index = ['A', 'B', 'C', 'D', 'E']
s1
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
s1.index = range(1001,1006)
s1
# Out:
# 1001    10
# 1002    20
# 1003    30
# 1004    40
# 1005    50
# dtype: int64

# %%
s1.index = [1.5,2.5,3.5,4.5,5.7]
s1
# Out:
# 1.5    10
# 2.5    20
# 3.5    30
# 4.5    40
# 5.7    50
# dtype: int64

# %%
s1.index = ['A', 'B', 'C', 'D', 'E']
s1
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
s1.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %% [markdown]
# ## Accessing data in Series

# %%
s1[3]
# Out:
# 40

# %%
s1["A"]
# Out:
# 10

# %%
s1[-1]
# Out:
# 50

# %%
s1['B']
# Out:
# 20

# %%
s1['D']
# Out:
# 40

# %%
s1.iloc[2]                  # By positional indexing
# Out:
# 30

# %%
s1.iloc[[0,1,4]] # returns a series of values present in the index list
# Out:
# A    10
# B    20
# E    50
# dtype: int64

# %%
s1.loc['A']                      # By index that has been provided
# Out:
# 10

# %%
s1.loc[['A','B','D']]
# Out:
# A    10
# B    20
# D    40
# dtype: int64

# %% [markdown]
# ## Add, update and Delete operations

# %%
s1
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
s1['F'] = 60
s1
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# F    60
# dtype: int64

# %%
s1['D'] = 80
s1
# Out:
# A    10
# B    20
# C    30
# D    80
# E    50
# F    60
# dtype: int64

# %%
s1.drop('D', inplace = True)    # inplace = True will make the change permanent in the original series

# %%
s1
# Out:
# A    10
# B    20
# C    30
# E    50
# F    60
# dtype: int64

# %% [markdown]
# ## Slicing

# %%
s1[:4]
# Out:
# A    10
# B    20
# C    30
# E    50
# dtype: int64

# %%
s1[2:5]
# Out:
# C    30
# E    50
# F    60
# dtype: int64

# %%
s1[-1::-1]
# Out:
# F    60
# E    50
# C    30
# B    20
# A    10
# dtype: int64

# %%
s1[::2]
# Out:
# A    10
# C    30
# F    60
# dtype: int64

# %% [markdown]
# ## Creating Series from Dictionary

# %%
data = {'Mohit' : 85,
        'Ankit' : 80,
        'Anjali': 86,
        'Varun' : 81}
s = pd.Series(data)
s
# Out:
# Mohit     85
# Ankit     80
# Anjali    86
# Varun     81
# dtype: int64

# %%
s["Mohit"]
# Out:
# 85

# %%
data = {'Jaipur' : 'Rajasthan',
        'Mumbai' : 'Maharashtra',
        'Kolkata': 'West Bengal',
        'Chandigarh' : 'Punjab',
        'Bengaluru' : 'Karnataka'}
data
# Out:
# {'Jaipur': 'Rajasthan',
#  'Mumbai': 'Maharashtra',
#  'Kolkata': 'West Bengal',
#  'Chandigarh': 'Punjab',
#  'Bengaluru': 'Karnataka'}

# %%
s2 = pd.Series(data)
s2
# Out:
# Jaipur          Rajasthan
# Mumbai        Maharashtra
# Kolkata       West Bengal
# Chandigarh         Punjab
# Bengaluru       Karnataka
# dtype: object

# %%
s2['Jaipur']
# Out:
# 'Rajasthan'

# %%
s2[0]
# Out:
# 'Rajasthan'

# %%
s2.index
# Out:
# Index(['Jaipur', 'Mumbai', 'Kolkata', 'Chandigarh', 'Bengaluru'], dtype='object')

# %%
s2.values
# Out:
# array(['Rajasthan', 'Maharashtra', 'West Bengal', 'Punjab', 'Karnataka'],
#       dtype=object)

# %%
s2[3]
# Out:
# 'Punjab'

# %%
s2.loc['Jaipur']
# Out:
# 'Rajasthan'

# %%
s2.iloc[0]
# Out:
# 'Rajasthan'

# %%
s2.name = 'States and Capitals'
s2
# Out:
# Jaipur          Rajasthan
# Mumbai        Maharashtra
# Kolkata       West Bengal
# Chandigarh         Punjab
# Bengaluru       Karnataka
# Name: States and Capitals, dtype: object

# %%
s2.name
# Out:
# 'States and Capitals'

# %%
s2.index.name = 'Capitals'
s2
# Out:
# Capitals
# Jaipur          Rajasthan
# Mumbai        Maharashtra
# Kolkata       West Bengal
# Chandigarh         Punjab
# Bengaluru       Karnataka
# Name: States and Capitals, dtype: object

# %%
print(s2.index)
print(s2.values)
print(s2.dtype)
print(s2.name)
print(s2.index.name)
# Out:
# Index(['Jaipur', 'Mumbai', 'Kolkata', 'Chandigarh', 'Bengaluru'], dtype='object', name='Capitals')
# ['Rajasthan' 'Maharashtra' 'West Bengal' 'Punjab' 'Karnataka']
# object
# States and Capitals
# Capitals

# %%
s2[['Jaipur','Mumbai','Kolkata']]
# Out:
# Capitals
# Jaipur       Rajasthan
# Mumbai     Maharashtra
# Kolkata    West Bengal
# Name: States and Capitals, dtype: object

# %%
roll_no = [101,102,103,104,105]
result = [88,89,93,85,96]

s3 = pd.Series(data = result, index = roll_no)
s3.name = 'Final Result'
s3.index.name = 'Roll No'
s3
# Out:
# Roll No
# 101    88
# 102    89
# 103    93
# 104    85
# 105    96
# Name: Final Result, dtype: int64

# %%
s2
# Out:
# Capitals
# Jaipur          Rajasthan
# Mumbai        Maharashtra
# Kolkata       West Bengal
# Chandigarh         Punjab
# Bengaluru       Karnataka
# Name: States and Capitals, dtype: object

# %%
capitals = ['Jaipur', 'Kolkata', 'Mumbai']
s4 = pd.Series(data = s2, index = capitals)
s4
# Out:
# Jaipur       Rajasthan
# Kolkata    West Bengal
# Mumbai     Maharashtra
# Name: States and Capitals, dtype: object

# %%
capitals = ['Jaipur', 'Kolkata', 'Mumbai', 'Delhi','Chennai']
s5 = pd.Series(data = s2, index = capitals)
s5
# Out:
# Jaipur       Rajasthan
# Kolkata    West Bengal
# Mumbai     Maharashtra
# Delhi              NaN
# Chennai            NaN
# Name: States and Capitals, dtype: object

# %% [markdown]
# ## Functions

# %%
s5.isnull()                               # Check for missing values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f58632edeca6> in <cell line: 1>()
# ----> 1 s5.isnull()                               # Check for missing values
#
# NameError: name 's5' is not defined

# %%
s5.notnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d3b4e08603a4> in <cell line: 1>()
# ----> 1 s5.notnull()
#
# NameError: name 's5' is not defined

# %%
s5.isnull().sum()     # Number of missing values

# %%
s5.notnull().sum()

# %%
s5['Bengaluru'] = 'Karnataka'
s5

# %%
s5.head(2)

# %%
s5.head(5)

# %%
s5.head(3)

# %%
s5.tail()

# %%
s5.tail(3)

# %%
s5['Pune'] = 'Maharashtra'
s5

# %%
s5.index = range(101,108)
s5

# %%
s5[108] = 'Maharashtra'
s5[109] = 'Maharashtra'
s5

# %%
s5.duplicated()                                   # Check for duplicate values

# %%
s5.duplicated().sum()

# %%
s5.dropna()

# %%
s5.dropna(inplace = True)

# %%
s5.dropna().duplicated()

# %%
s5.drop_duplicates(inplace = True)   # Drop duplicates

# %%
s5
